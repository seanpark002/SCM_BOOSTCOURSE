# %% [markdown]
# <a href="https://colab.research.google.com/github/seanpark002/SCM_BOOSTCOURSE/blob/main/5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 라이브러리 로드

# %%
# 데이터 분석을 위한 pandas 라이브러리를 불러옵니다.
# 데이터 시각화를 위한 seaborn 을 불러옵니다.
import pandas as pd
import seaborn as sns

# %%
print(pd.__version__)
print(sns.__version__)
# Out:
# 2.2.2
# 0.13.2

# %%
# 0.11.0 버전에서 변화가 많으니 이 버전 이상을 사용해 주세요.
# !pip install seaborn --upgrade

# %% [markdown]
# ## 데이터셋 불러오기
# <img src="https://pandas.pydata.org/docs/_images/02_io_readwrite.svg">
#
# * seaborn 데이터셋 위치 : https://github.com/mwaskom/seaborn-data

# %%
# df
df = sns.load_dataset('mpg')

# %% [markdown]
# ## 데이터셋 일부만 가져오기

# %%
# head
df.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
# tail
df.tail(3)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin           name
# 395          82    usa  dodge rampage
# 396          82    usa    ford ranger
# 397          82    usa     chevy s-10

# %%
# sample
df.sample(3)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 291  19.2          8         267.0       125.0    3605          15.0
# 130  26.0          4         122.0        80.0    2451          16.5
# 70   13.0          8         400.0       190.0    4422          12.5
#
#      model_year origin                           name
# 291          79    usa  chevrolet malibu classic (sw)
# 130          74    usa                     ford pinto
# 70           72    usa         chrysler newport royal

# %% [markdown]
# ## 매번 봐야 하는 기술통계값 코드 한 줄로 보기
# ### Pandas Profiling
# * [pandas-profiling/pandas-profiling: Create HTML profiling reports from pandas DataFrame objects](https://github.com/pandas-profiling/pandas-profiling)

# %%
# 아래 명령어로 설치합니다.
# !pip install pandas_profiling --upgrade
# !pip install ydata-profiling

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df, title="Pandas Profiling Report")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# /tmp/ipython-input-870772761.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
# 주피터 노트북이 있는 위치에 html파일이 생성됩니다.
profile.to_file("pandas_profile_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### sweetviz
# * [sweetviz · PyPI](https://pypi.org/project/sweetviz/)
# <img src="https://warehouse-camo.ingress.cmh1.psfhosted.org/210c4eb7317c8b0d2e7d0784b1a9697c096050ef/687474703a2f2f636f6f6c74696d696e672e636f6d2f53562f4c61796f75742d416e696d332e676966">

# %%
# 아래 명령어로 설치해 주셔야지 사용할 수 있습니다.
# !pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 77.2 MB/s eta 0:00:00
# ...

# %%
pip install numpy==1.23.5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 61.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
pip install --upgrade sweetviz
